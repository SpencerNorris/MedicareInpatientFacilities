# %% [markdown]
# Raw CSV files acquired from (https://data.medicare.gov/data/inpatient-rehabilitation-facility-compare).

# %%
import pandas as pd

# %%
conditions = pd.read_csv('data/Inpatient_Rehab_Facilities_-_Revised_Flat_Files/Inpatient Rehab Facility - Conditions.csv')
general_info = pd.read_csv('data/Inpatient_Rehab_Facilities_-_Revised_Flat_Files/Inpatient Rehab Facility - General Information.csv')
provider_data = pd.read_csv('data/Inpatient_Rehab_Facilities_-_Revised_Flat_Files/Inpatient Rehab Facility - Provider data.csv')
national_data = pd.read_csv('data/Inpatient_Rehab_Facilities_-_Revised_Flat_Files/Inpatient Rehab Facility - National data.csv')

# %%
provider_data
# Out:
#       CMS Certification Number (CCN)  \
# 0                             013025
# 1                             013025
# 2                             013025
# 3                             013025
# 4                             013025
# 5                             013025
# 6                             013025
# 7                             013025
# 8                             013025
# 9                             013025
# 10                            013025
# 11                            013025
# 12                            013025
# 13                            013025
# 14                            013025
# 15                            013025
# 16                            013025
# 17                            013025
# 18                            013025
# 19                            013025
# 20                            013025
# 21                            013025
# 22                            013025
# 23                            013025
# 24                            013025
# 25                            013025
# 26                            013025
# 27                            013025
# 28                            013025
# 29                            013025
# ...                              ...
# 38114                         673065
# 38115                         673065
# 38116                         673065
# 38117                         673065
# 38118                         673065
# 38119                         673065
# 38120                         673065
# 38121                         673065
# 38122                         673065
# 38123                         673065
# 38124                         673065
# 38125                         673065
# 38126                         673065
# 38127                         673065
# 38128                         673065
# 38129                         673065
# 38130                         673065
# 38131                         673065
# 38132                         673065
# 38133                         673065
# 38134                         673065
# 38135                         673065
# 38136                         673065
# 38137                         673065
# 38138                         673065
# 38139                         673065
# 38140                         673065
# 38141                         673065
# 38142                         673065
# 38143                         673065
#
#                                            Facility Name       Address Line 1  \
# 0          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 1          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 2          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 3          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 4          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 5          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 6          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 7          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 8          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 9          HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 10         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 11         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 12         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 13         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 14         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 15         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 16         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 17         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 18         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 19         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 20         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 21         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 22         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 23         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 24         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 25         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 26         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 27         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 28         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# 29         HEALTHSOUTH LAKESHORE REHABILITATION HOSPITAL  3800 RIDGEWAY DRIVE
# ...                                                  ...                  ...
# 38114  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38115  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38116  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38117  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38118  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38119  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38120  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38121  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38122  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38123  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38124  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38125  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38126  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38127  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38128  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38129  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38130  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38131  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38132  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38133  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38134  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38135  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38136  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38137  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38138  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38139  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38140  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38141  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38142  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
# 38143  CHI ST JOSEPH HEALTHSOUTH REHABILITATION HOSPITAL       1600 JOSEPH DR
#
#       Address Line 2        City State  Zip Code County Name     PhoneNumber  \
# 0                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 1                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 2                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 3                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 4                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 5                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 6                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 7                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 8                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 9                NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 10               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 11               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 12               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 13               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 14               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 15               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 16               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 17               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 18               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 19               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 20               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 21               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 22               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 23               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 24               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 25               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 26               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 27               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 28               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 29               NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# ...              ...         ...   ...       ...         ...             ...
# 38114            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38115            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38116            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38117            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38118            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38119            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38120            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38121            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38122            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38123            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38124            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38125            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38126            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38127            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38128            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38129            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38130            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38131            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38132            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38133            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38134            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38135            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38136            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38137            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38138            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38139            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38140            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38141            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38142            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
# 38143            NaN       BRYAN    TX     77802      Brazos  (979) 821-7506
#
#        CMS Region          Measure Code  \
# 0               4     I_001_01_ADJ_RATE
# 1               4  I_001_01_DENOMINATOR
# 2               4  I_002_01_DENOMINATOR
# 3               4     I_002_01_OBS_RATE
# 4               4     I_006_01_CI_LOWER
# 5               4     I_006_01_CI_UPPER
# 6               4    I_006_01_COMP_PERF
# 7               4    I_006_01_DOPC_DAYS
# 8               4    I_006_01_ELIGCASES
# 9               4    I_006_01_NUMERATOR
# 10              4          I_006_01_SIR
# 11              4    I_007_01_COMP_PERF
# 12              4         I_007_01_RSRR
# 13              4     I_007_01_RSRR_2_5
# 14              4    I_007_01_RSRR_97_5
# 15              4       I_007_01_VOLUME
# 16              4     I_014_01_CI_LOWER
# 17              4     I_014_01_CI_UPPER
# 18              4    I_014_01_COMP_PERF
# 19              4    I_014_01_DOPC_DAYS
# 20              4    I_014_01_ELIGCASES
# 21              4    I_014_01_NUMERATOR
# 22              4          I_014_01_SIR
# 23              4     I_015_01_CI_LOWER
# 24              4     I_015_01_CI_UPPER
# 25              4    I_015_01_COMP_PERF
# 26              4    I_015_01_DOPC_DAYS
# 27              4    I_015_01_ELIGCASES
# 28              4    I_015_01_NUMERATOR
# 29              4          I_015_01_SIR
# ...           ...                   ...
# 38114           6  I_002_01_DENOMINATOR
# 38115           6     I_002_01_OBS_RATE
# 38116           6     I_006_01_CI_LOWER
# 38117           6     I_006_01_CI_UPPER
# 38118           6    I_006_01_COMP_PERF
# 38119           6    I_006_01_DOPC_DAYS
# 38120           6    I_006_01_ELIGCASES
# 38121           6    I_006_01_NUMERATOR
# 38122           6          I_006_01_SIR
# 38123           6    I_007_01_COMP_PERF
# 38124           6         I_007_01_RSRR
# 38125           6     I_007_01_RSRR_2_5
# 38126           6    I_007_01_RSRR_97_5
# 38127           6       I_007_01_VOLUME
# 38128           6     I_014_01_CI_LOWER
# 38129           6     I_014_01_CI_UPPER
# 38130           6    I_014_01_COMP_PERF
# 38131           6    I_014_01_DOPC_DAYS
# 38132           6    I_014_01_ELIGCASES
# 38133           6    I_014_01_NUMERATOR
# 38134           6          I_014_01_SIR
# 38135           6     I_015_01_CI_LOWER
# 38136           6     I_015_01_CI_UPPER
# 38137           6    I_015_01_COMP_PERF
# 38138           6    I_015_01_DOPC_DAYS
# 38139           6    I_015_01_ELIGCASES
# 38140           6    I_015_01_NUMERATOR
# 38141           6          I_015_01_SIR
# 38142           6  I_016_01_DENOMINATOR
# 38143           6     I_016_01_OBS_RATE
#
#                                           Score Footnote  Start Date  \
# 0                                           0.7      NaN  04/01/2016
# 1                                          2259      NaN  04/01/2016
# 2                                 Not Available        4  10/01/2016
# 3                                 Not Available        4  10/01/2016
# 4                                         0.151      NaN  04/01/2016
# 5                                         2.972      NaN  04/01/2016
# 6      No Different than the National Benchmark      NaN  04/01/2016
# 7                                          1568      NaN  04/01/2016
# 8                                         2.223      NaN  04/01/2016
# 9                                             2      NaN  04/01/2016
# 10                                        0.900      NaN  04/01/2016
# 11                                Not Available        4  01/01/2014
# 12                                Not Available        4  01/01/2014
# 13                                Not Available        4  01/01/2014
# 14                                Not Available        4  01/01/2014
# 15                                Not Available        4  01/01/2014
# 38143  03/31/2017
#
# [38144 rows x 15 columns]

# %% [markdown]
# Let's start by finding out how many of the providers here are missing any data at all.

# %%
#Get total number of unique CCNs
total_ccns = len(provider_data["CMS Certification Number (CCN)"].unique())

#Check if there's any missing data for each CCN
missing_data_ccns = []
for ccn in provider_data["CMS Certification Number (CCN)"].unique():
    subset = provider_data.loc[provider_data["CMS Certification Number (CCN)"] == ccn]
    if subset["Score"].str.contains("Not Available").any():
        missing_data_ccns.append(ccn)
        
print("Number of facilities with missing data: ", len(missing_data_ccns))
print((float(len(missing_data_ccns)) / float(total_ccns)) * 100, "% of all facilities missing data.")
# Out:
# Number of facilities with missing data:  1192
# 100.0 % of all facilities missing data.

# %% [markdown]
# Well that's reassuring. Every single facility is missing a value for at least one field.
#
# We can start by looking at individual metrics and moving from there. Let's start by looking at the rate of patient readmission.

# %%
#Select all rows that measure the number of stays and hte patient readmission rate
readmission_rates = provider_data.loc[
    (provider_data["Measure Code"] == "I_007_01_RSRR") | 
    (provider_data["Measure Code"] == "I_007_01_VOLUME")]

# %%
#Find all CCNs we want to filter out
filtered_ccns = []
for ccn in readmission_rates["CMS Certification Number (CCN)"].unique():
    #This is funky; just says if either of our two values for that CCN is "Not Available",
    #We'll drop that particular CCN altogether.
    if readmission_rates.loc[readmission_rates["CMS Certification Number (CCN)"] == ccn]["Score"].str.contains("Not Available").any():
        filtered_ccns.append(ccn)

        

print(len(readmission_rates.loc[readmission_rates["Score"].str.contains("Not Available")]),
      "out of a possible ", total_ccns, "facilities.")
# Out:
# 275 out of a possible  1192 facilities.

# %% [markdown]
# I feel comfortable just dropping those facilities; it does account for about 23% of the dataset, which is a lot, but it won't kill us.

# %%
#Drop providers without readmission rate
readmission_rates = readmission_rates.loc[~(readmission_rates["Score"].str.contains("Not Available"))]

# %%
#Convert readmission rates to numeric values
readmission_rates["Score"] = readmission_rates["Score"].apply(pd.to_numeric)
readmission_rates.describe()
# Out:
#            Zip Code   CMS Region        Score
# count   2109.000000  2109.000000  2109.000000
# mean   51922.667141     5.240398   251.521679
# std    26988.402353     2.173359   412.269217
# min      674.000000     1.000000     5.000000
# 25%    30033.000000     4.000000    13.360000
# 50%    50309.000000     5.000000    17.000000
# 75%    75482.000000     6.000000   329.000000
# max    99519.000000    10.000000  6393.000000

# %% [markdown]
# So at each end of the spectrum, we have a minimum readmission rate of 10.9% and a maximum of 15.84%. Is this in any way connected to the number of patients that each facility has to care for?

# %%
#Reformat provider_data so that each row is a facility and its constituent measures
# ccndict = {"CMS Certification Number (CCN)" : [ccn for ccn in provider_data["CMS Certification Number (CCN)"].unique()]}
datadict = dict([(measure, pd.Series([])) for measure in provider_data["Measure Code"].unique()])
datadict = {**datadict,**{"CMS Certification Number (CCN)" : pd.Series([])}}


#Really inefficient, but there's not a great way of doing this as far as I can see
facility_data = provider_data.groupby(provider_data["CMS Certification Number (CCN)"])
for name, group in facility_data:
    for measure in group["Measure Code"].unique():
        datadict[measure].append(group.loc[group["Measure Code"] == measure]["Score"])
        datadict["CMS Certification Number (CCN)"].append(pd.Series(name))

# %%
readmission_rates
# Out:
# Empty DataFrame
# Columns: [I_007_01_RSRR, I_007_01_VOLUME]
# Index: []
